# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
loan_default = pd.read_csv("Loan_default.csv")

# %%
loan_default.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
loan_default.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# ...

# %%
dataset_loan = loan_default.copy()
dataset_loan = dataset_loan[['Age', 'Income', 'LoanAmount', 'MonthsEmployed', 'NumCreditLines', 'InterestRate',
                       'LoanTerm', 'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
                       'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner', 'Default']]

# %%
dataset_loan.shape
# Out:
# (255347, 16)

# %%
dataset_loan
# Out:
#         Age  Income  LoanAmount  MonthsEmployed  NumCreditLines  InterestRate  \
# 0        56   85994       50587              80               4         15.23
# 1        69   50432      124440              15               1          4.81
# 2        46   84208      129188              26               3         21.17
# 3        32   31713       44799               0               3          7.07
# 4        60   20437        9139               8               4          6.51
# ...     ...     ...         ...             ...             ...           ...
# 255342   19   37979      210682             109               4         14.11
# 255343   32   51953      189899              14               2         11.55
# 255344   56   84820      208294              70               3          5.29
# 255345   42   85109       60575              40               1         20.90
# 255346   62   22418       18481             113               2          6.73
#
# ...

# %%
dataset_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Age             255347 non-null  int64
#  1   Income          255347 non-null  int64
#  2   LoanAmount      255347 non-null  int64
#  3   MonthsEmployed  255347 non-null  int64
#  4   NumCreditLines  255347 non-null  int64
#  5   InterestRate    255347 non-null  float64
#  6   LoanTerm        255347 non-null  int64
#  7   DTIRatio        255347 non-null  float64
#  8   Education       255347 non-null  object
#  9   EmploymentType  255347 non-null  object
#  10  MaritalStatus   255347 non-null  object
#  11  HasMortgage     255347 non-null  object
#  12  HasDependents   255347 non-null  object
#  13  LoanPurpose     255347 non-null  object
#  14  HasCoSigner     255347 non-null  object
#  15  Default         255347 non-null  int64
# dtypes: float64(2), int64(7), object(7)
# ...

# %%
dataset_loan.nunique()
# Out:
# Age                   52
# Income            114620
# LoanAmount        158729
# MonthsEmployed       120
# NumCreditLines         4
# InterestRate        2301
# LoanTerm               5
# DTIRatio              81
# Education              4
# EmploymentType         4
# MaritalStatus          3
# HasMortgage            2
# HasDependents          2
# LoanPurpose            5
# HasCoSigner            2
# Default                2
# dtype: int64

# %% [markdown]
# ### 1. Age

# %%
dataset_loan['Age'].describe()
# Out:
# count    255347.000000
# mean         43.498306
# std          14.990258
# min          18.000000
# 25%          31.000000
# 50%          43.000000
# 75%          56.000000
# max          69.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(data=dataset_loan, x="Default", y="Age")
# Out:
# <Axes: xlabel='Default', ylabel='Age'>

# %% [markdown]
# ### 2. Income

# %%
dataset_loan['Income'].describe()
# Out:
# count    255347.000000
# mean      82499.304597
# std       38963.013729
# min       15000.000000
# 25%       48825.500000
# 50%       82466.000000
# 75%      116219.000000
# max      149999.000000
# Name: Income, dtype: float64

# %%
sns.boxplot(data=dataset_loan, x="Default", y="Income")
# Out:
# <Axes: xlabel='Default', ylabel='Income'>

# %% [markdown]
# ### 3. Loan Amount

# %%
dataset_loan['LoanAmount'].describe()
# Out:
# count    255347.000000
# mean     127578.865512
# std       70840.706142
# min        5000.000000
# 25%       66156.000000
# 50%      127556.000000
# 75%      188985.000000
# max      249999.000000
# Name: LoanAmount, dtype: float64

# %%
sns.boxplot(data=dataset_loan, x="Default", y="LoanAmount")
# Out:
# <Axes: xlabel='Default', ylabel='LoanAmount'>

# %% [markdown]
# ### 4. Months Employed

# %%
dataset_loan['MonthsEmployed'].describe()
# Out:
# count    255347.000000
# mean         59.541976
# std          34.643376
# min           0.000000
# 25%          30.000000
# 50%          60.000000
# 75%          90.000000
# max         119.000000
# Name: MonthsEmployed, dtype: float64

# %%
sns.boxplot(data=dataset_loan, x="Default", y="MonthsEmployed")
# Out:
# <Axes: xlabel='Default', ylabel='MonthsEmployed'>

# %% [markdown]
# ### 5. Number Credit Lines

# %%
dataset_loan['NumCreditLines'].describe()
# Out:
# count    255347.000000
# mean          2.501036
# std           1.117018
# min           1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# max           4.000000
# Name: NumCreditLines, dtype: float64

# %%
sns.boxplot(data=dataset_loan, x="Default", y="NumCreditLines")
# Out:
# <Axes: xlabel='Default', ylabel='NumCreditLines'>

# %% [markdown]
# ### 6. Interesting Rate

# %%
dataset_loan['InterestRate'].describe()
# Out:
# count    255347.000000
# mean         13.492773
# std           6.636443
# min           2.000000
# 25%           7.770000
# 50%          13.460000
# 75%          19.250000
# max          25.000000
# Name: InterestRate, dtype: float64

# %%
sns.boxplot(data=dataset_loan, x="Default", y="InterestRate")
# Out:
# <Axes: xlabel='Default', ylabel='InterestRate'>

# %% [markdown]
# ### 7. Loan Term

# %%
dataset_loan['LoanTerm'].describe()
# Out:
# count    255347.000000
# mean         36.025894
# std          16.969330
# min          12.000000
# 25%          24.000000
# 50%          36.000000
# 75%          48.000000
# max          60.000000
# Name: LoanTerm, dtype: float64

# %%
sns.boxplot(data=dataset_loan, x="Default", y="LoanTerm")
# Out:
# <Axes: xlabel='Default', ylabel='LoanTerm'>

# %% [markdown]
# ### 8. DTI Ratio

# %%
dataset_loan['DTIRatio'].describe()
# Out:
# count    255347.000000
# mean          0.500212
# std           0.230917
# min           0.100000
# 25%           0.300000
# 50%           0.500000
# 75%           0.700000
# max           0.900000
# Name: DTIRatio, dtype: float64

# %%
sns.boxplot(data=dataset_loan, x="Default", y="DTIRatio")
# Out:
# <Axes: xlabel='Default', ylabel='DTIRatio'>

# %% [markdown]
# ### 9. Education

# %%
dataset_loan['Education'].value_counts(normalize = True)
# Out:
# Education
# Bachelor's     0.252073
# High School    0.250259
# Master's       0.248842
# PhD            0.248826
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(13, 10))
sns.countplot(data=dataset_loan, x="Education", hue="Default")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %% [markdown]
# ### 10. Employment Type

# %%
dataset_loan['EmploymentType'].value_counts(normalize = True)
# Out:
# EmploymentType
# Part-time        0.251270
# Unemployed       0.249950
# Self-employed    0.249488
# Full-time        0.249292
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(13, 10))
sns.countplot(data=dataset_loan, x="EmploymentType", hue="Default")
# Out:
# <Axes: xlabel='EmploymentType', ylabel='count'>

# %% [markdown]
# ### 11. Marital Status

# %%
dataset_loan['MaritalStatus'].value_counts(normalize = True)
# Out:
# MaritalStatus
# Married     0.334063
# Divorced    0.333010
# Single      0.332927
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(13, 10))
sns.countplot(data=dataset_loan, x="MaritalStatus", hue="Default")
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# ### 12. Has Mortage

# %%
dataset_loan['HasMortgage'].value_counts(normalize = True)
# Out:
# HasMortgage
# Yes    0.500014
# No     0.499986
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(13, 10))
sns.countplot(data=dataset_loan, x="HasMortgage", hue="Default")
# Out:
# <Axes: xlabel='HasMortgage', ylabel='count'>

# %% [markdown]
# ### 13. Has Dependents

# %%
dataset_loan['HasDependents'].value_counts(normalize = True)
# Out:
# HasDependents
# Yes    0.500268
# No     0.499732
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(13, 10))
sns.countplot(data=dataset_loan, x="HasDependents", hue="Default")
# Out:
# <Axes: xlabel='HasDependents', ylabel='count'>

# %% [markdown]
# ### 14. Loan Purpose

# %%
dataset_loan['LoanPurpose'].value_counts(normalize = True)
# Out:
# LoanPurpose
# Business     0.200895
# Home         0.200848
# Education    0.199748
# Other        0.199391
# Auto         0.199117
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(13, 10))
sns.countplot(data=dataset_loan, x="LoanPurpose", hue="Default")
# Out:
# <Axes: xlabel='LoanPurpose', ylabel='count'>

# %% [markdown]
# ### 15. Has Co Signer

# %%
dataset_loan['HasCoSigner'].value_counts(normalize = True)
# Out:
# HasCoSigner
# Yes    0.500108
# No     0.499892
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(13, 10))
sns.countplot(data=dataset_loan, x="HasCoSigner", hue="Default")
# Out:
# <Axes: xlabel='HasCoSigner', ylabel='count'>
